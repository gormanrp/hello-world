# %% [markdown]
# # Win-Loss Percentages

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
run winlosspct.py
# Out:
# MLB Winning Pct, 2018. Std Dev = 0.09
# NBA Winning Pct, 2018. Std Dev = 0.149
# NFL Winning Pct, 2018. Std Dev = 0.181
# EPL Winning Pct, 2018. Std Dev = 0.16

# %%
df_all.index = range(1,len(df_all)+1)
print(df_all.head())
# Out:
#    Year League                  Team     W     L    T       Pct
# 1  2018    EPL       Manchester City  32.0   2.0  4.0  0.894737
# 2  2018    NFL     Los Angeles Rams*  13.0   3.0  0.0  0.812500
# 3  2018    NFL   New Orleans Saints*  13.0   3.0  0.0  0.812500
# 4  2018    NBA  Houston Rockets* (1)  65.0  17.0  0.0  0.792683
# 5  2018    NFL        Chicago Bears*  12.0   4.0  0.0  0.750000

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x=df_all[df_all.Year==2018].League,y=df_all.Pct)
sns.swarmplot(x=df_all[df_all.Year==2018].League,y=df_all.Pct, color='black')
plt.ylim(0,1)
plt.title(2018)
# Out:
# Text(0.5, 1.0, '2018')
